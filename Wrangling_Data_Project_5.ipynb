# %%
import pandas as pd

# %%
with open('/COL_Names.txt', 'r') as file:
    content = file.read().strip()
    # Extract column names from the string
    columns = content.split('=')[1].strip(' []').replace("'", "").split(', ')

df = pd.read_csv('/Wrangling data.txt', header=None, names=columns)

df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df[['length', 'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders']]
# Out:
#      length  width  height  curb-weight engine-type num-of-cylinders
# 0     168.8   64.1    48.8         2548        dohc             four
# 1     168.8   64.1    48.8         2548        dohc             four
# 2     171.2   65.5    52.4         2823        ohcv              six
# 3     176.6   66.2    54.3         2337         ohc             four
# 4     176.6   66.4    54.3         2824         ohc             five
# ..      ...    ...     ...          ...         ...              ...
# 200   188.8   68.9    55.5         2952         ohc             four
# 201   188.8   68.8    55.5         3049         ohc             four
# 202   188.8   68.9    55.5         3012        ohcv              six
# 203   188.8   68.9    55.5         3217         ohc              six
# 204   188.8   68.9    55.5         3062         ohc             four
#
# [205 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
list(df)
# Out:
# ['symboling',
#  'normalized-losses',
#  'make',
#  'fuel-type',
#  'aspiration',
#  'num-of-doors',
#  'body-style',
#  'drive-wheels',
#  'engine-location',
#  'wheel-base',
#  'length',
#  'width',
#  'height',
#  'curb-weight',
#  'engine-type',
#  'num-of-cylinders',
#  'engine-size',
#  'fuel-system',
#  'bore',
#  'stroke',
#  'compression-ratio',
#  'horsepower',
#  'peak-rpm',
#  'city-mpg',
#  'highway-mpg',
#  'price']

# %%
df.sample(5)
# Out:
#      symboling normalized-losses        make fuel-type aspiration  \
# 127          3                 ?     porsche       gas        std
# 66           0                 ?       mazda    diesel        std
# 184          2                94  volkswagen    diesel        std
# 57           3               150       mazda       gas        std
# 61           1               129       mazda       gas        std
#
#     num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# 127          two    hardtop          rwd            rear        89.5  ...
# 66          four      sedan          rwd           front       104.9  ...
# 184         four      sedan          fwd           front        97.3  ...
# 57           two  hatchback          rwd           front        95.3  ...
# 61           two  hatchback          fwd           front        98.8  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
# df['symboling'].value_counts()
# df['normalized-losses'].value_counts()
df['make'].value_counts()
# df['fuel-type'].value_counts()
# df['aspiration'].value_counts()
# df['num-of-doors'].value_counts()
# df['body-style'].value_counts()
# df['drive-wheels'].value_counts()
# df['engine-location'].value_counts()
# df['wheel-base'].value_counts()
# df['length'].value_counts()
# df['width'].value_counts()
# df['height'].value_counts()
# df['curb-weight'].value_counts()
# df['engine-type'].value_counts()
# df['num-of-cylinders'].value_counts()
# df['engine-size'].value_counts()
# df['fuel-system'].value_counts()
# df['bore'].value_counts()
# df['stroke'].value_counts()
# df['compression-ratio'].value_counts()
# df['horsepower'].value_counts()
# df['peak-rpm'].value_counts()
# df['city-mpg'].value_counts()
# df['highway-mpg'].value_counts()
# df['price'].value_counts()

# df['normalized-losses'].max()
# df[df['curb-weight'] < 2000]
# Out:
# make
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# renault           2
# mercury           1
# Name: count, dtype: int64

# %%
filter_df = df.query('make in ["Dodge", "Chevrolet", "Isuzu"]')
filter_df
# Out:
# Empty DataFrame
# Columns: [symboling, normalized-losses, make, fuel-type, aspiration, num-of-doors, body-style, drive-wheels, engine-location, wheel-base, length, width, height, curb-weight, engine-type, num-of-cylinders, engine-size, fuel-system, bore, stroke, compression-ratio, horsepower, peak-rpm, city-mpg, highway-mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
filter_df[['length', 'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders']]
# Out:
# Empty DataFrame
# Columns: [length, width, height, curb-weight, engine-type, num-of-cylinders]
# Index: []

# %%
# df[df['curb-weight'] < 2000]['curb-weight']

# %%
# df[df['symboling'].duplicated()]
# df[df['normalized-losses'].duplicated()]
# df[df['make'].duplicated()]
# df[df['fuel-type'].duplicated()]
# df[df['aspiration'].duplicated()]
# df[df['num-of-doors'].duplicated()]
# df[df['body-style'].duplicated()]
# df[df['drive-wheels'].duplicated()]
# df[df['engine-location'].duplicated()]
# df[df['wheel-base'].duplicated()]
# df[df['length'].duplicated()]
# df[df['width'].duplicated()]
# df[df['height'].duplicated()]
# df[df['curb-weight'].duplicated()]
# df[df['engine-type'].duplicated()]
# df[df['num-of-cylinders'].duplicated()]
# df[df['engine-size'].duplicated()]
# df[df['fuel-system'].duplicated()]
# df[df['bore'].duplicated()]
# df[df['stroke'].duplicated()]
# df[df['compression-ratio'].duplicated()]
# df[df['horsepower'].duplicated()]
# df[df['peak-rpm'].duplicated()]
# df[df['city-mpg'].duplicated()]
# df[df['highway-mpg'].duplicated()]
df[df['price'].duplicated()]
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 2            1                 ?  alfa-romero       gas        std
# 36           0                78        honda       gas        std
# 44           1                 ?        isuzu       gas        std
# 45           0                 ?        isuzu       gas        std
# 59           1               129        mazda       gas        std
# 88          -1               137   mitsubishi       gas        std
# 103          0               108       nissan       gas        std
# 118          1               119     plymouth       gas        std
# 119          1               119     plymouth       gas      turbo
# 120          1               154     plymouth       gas        std
# 121          1               154     plymouth       gas        std
# 122          1               154     plymouth       gas        std
# 123         -1                74     plymouth       gas        std
# ...

# %%
filtered_df = df[df['curb-weight'] == 4066]
filtered_df
# Out:
#     symboling normalized-losses    make fuel-type aspiration num-of-doors  \
# 47          0               145  jaguar       gas        std         four
# 48          0                 ?  jaguar       gas        std         four
#
#    body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 47      sedan          rwd           front       113.0  ...          258
# 48      sedan          rwd           front       113.0  ...          258
#
#     fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 47         mpfi  3.63    4.17               8.1        176      4750       15
# 48         mpfi  3.63    4.17               8.1        176      4750       15
#
#    highway-mpg  price
# 47          19  32250
# 48          19  35550
#
# [2 rows x 26 columns]

# %%
filtered_df = df[df['normalized-losses'] == '?']
filtered_df
# Out:
#      symboling normalized-losses           make fuel-type aspiration  \
# 0            3                 ?    alfa-romero       gas        std
# 1            3                 ?    alfa-romero       gas        std
# 2            1                 ?    alfa-romero       gas        std
# 5            2                 ?           audi       gas        std
# 7            1                 ?           audi       gas        std
# 9            0                 ?           audi       gas      turbo
# 14           1                 ?            bmw       gas        std
# 15           0                 ?            bmw       gas        std
# 16           0                 ?            bmw       gas        std
# 17           0                 ?            bmw       gas        std
# 43           0                 ?          isuzu       gas        std
# 44           1                 ?          isuzu       gas        std
# 45           0                 ?          isuzu       gas        std
# ...

# %%
filtered_df = df[df['make'] == 'mazda']
filtered_df
# Out:
#     symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 50          1               104  mazda       gas        std          two
# 51          1               104  mazda       gas        std          two
# 52          1               104  mazda       gas        std          two
# 53          1               113  mazda       gas        std         four
# 54          1               113  mazda       gas        std         four
# 55          3               150  mazda       gas        std          two
# 56          3               150  mazda       gas        std          two
# 57          3               150  mazda       gas        std          two
# 58          3               150  mazda       gas        std          two
# 59          1               129  mazda       gas        std          two
# 60          0               115  mazda       gas        std         four
# 61          1               129  mazda       gas        std          two
# ...

# %%
filtered_df[['length','width','height']]
# Out:
#     length  width  height
# 50   159.1   64.2    54.1
# 51   159.1   64.2    54.1
# 52   159.1   64.2    54.1
# 53   166.8   64.2    54.1
# 54   166.8   64.2    54.1
# 55   169.0   65.7    49.6
# 56   169.0   65.7    49.6
# 57   169.0   65.7    49.6
# 58   169.0   65.7    49.6
# 59   177.8   66.5    53.7
# 60   177.8   66.5    55.5
# 61   177.8   66.5    53.7
# 62   177.8   66.5    55.5
# 63   177.8   66.5    55.5
# 64   177.8   66.5    55.5
# 65   175.0   66.1    54.4
# 66   175.0   66.1    54.4

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %% [markdown]
# ## Quality
#
# *  '?' charachter cause some duplicate in `normalized-losses` , `price` **Can't Solve it AS it causes lose alot of data**
#   * NOTE duplicated in rows but different in column `price`
# *   There is an issue 31 row when `curb-weigt` less than 2000 As the regular range is (2000 - 4069) **Can't solve it**
#
#
# ## Tidiness
#
# *   Rename `Make` Cloumn with `Vehicle-Types`
#
# * *Add units to column name* :
#   *   Rename `wheel-base` column with `wheel-base_in` refer the unit of it by inches
#
#   *   Rename `length` column with `length-in` refer the unit of it by inche
#   *   Rename `width` column with `width-in` refer the unit of it by inche
#   *   Rename `height` column with `height-in` refer the unit of it by inche
#   *   Rename `engine-size` column with `engine-size-cu_in` refer the unit of it by inche
#   *   Rename `curb-weight` column with `curb-weight-lbs` refer the unit of it by inche

# %% [markdown]
# # Clean

# %%
df_clean = df.copy()

# %% [markdown]
# ## **Quality Issues**

# %% [markdown]
# ### Missing Value

# %% [markdown]
# ###### Define

# %% [markdown]
# Handle '?' in `normalized-losses`

# %% [markdown]
# ###### Code

# %%
df_clean['normalized-losses'] = df_clean['normalized-losses'].replace('?', None)

# %% [markdown]
# ###### Test

# %%
df_clean['normalized-losses'].value_counts()
# Out:
# normalized-losses
# 161    11
# 91      8
# 150     7
# 128     6
# 134     6
# 104     6
# 95      5
# 102     5
# 103     5
# 74      5
# 85      5
# 168     5
# 94      5
# 65      5
# 106     4
# 122     4
# 148     4
# 118     4
# 93      4
# 101     3
# 125     3
# 137     3
# 154     3
# 83      3
# 115     3
# 119     2
# 87      2
# 194     2
# 197     2
# 108     2
# 89      2
# 164     2
# 158     2
# 145     2
# 192     2
# 188     2
# 81      2
# 110     2
# 113     2
# 129     2
# 153     2
# 107     1
# 78      1
# 186     1
# 231     1
# 77      1
# 98      1
# 121     1
# 90      1
# 142     1
# 256     1
# Name: count, dtype: int64

# %% [markdown]
# ###### Define

# %% [markdown]
# Handle '?' in `Price`

# %% [markdown]
# ###### Code

# %%
df_clean['price'] = df_clean['price'].replace('?', None)

# %% [markdown]
# ###### Test

# %%
df_clean['price'].value_counts()
# Out:
# price
# 8921     2
# 18150    2
# 8845     2
# 8495     2
# 7609     2
#         ..
# 45400    1
# 16503    1
# 5389     1
# 6189     1
# 22625    1
# Name: count, Length: 186, dtype: int64

# %% [markdown]
# # Tidiness Issues

# %% [markdown]
# ###### Defien

# %% [markdown]
#  Rename Column `make` to `Vehicle-Types` to make the name of variable related to the values

# %% [markdown]
# ###### Code

# %%
df_clean.rename(columns={'make': 'Vehicle-Types'}, inplace=True)

# %% [markdown]
# ###### Test

# %%
df_clean.head()
# Out:
#    symboling normalized-losses Vehicle-Types fuel-type aspiration  \
# 0          3              None   alfa-romero       gas        std
# 1          3              None   alfa-romero       gas        std
# 2          1              None   alfa-romero       gas        std
# 3          2               164          audi       gas        std
# 4          2               164          audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %% [markdown]
# ### Add units to column name

# %% [markdown]
# ###### Define

# %% [markdown]
# Rename `wheel-base` column with `wheel-base_in` refer the unit of it by inches

# %% [markdown]
# ###### Code

# %%
df_clean.rename(columns={'wheel-base': 'wheel-base_in'}, inplace=True)

# %% [markdown]
# ###### Test

# %%
df_clean.head()
# Out:
#    symboling normalized-losses Vehicle-Types fuel-type aspiration  \
# 0          3              None   alfa-romero       gas        std
# 1          3              None   alfa-romero       gas        std
# 2          1              None   alfa-romero       gas        std
# 3          2               164          audi       gas        std
# 4          2               164          audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base_in  ...  \
# 0          two  convertible          rwd           front           88.6  ...
# 1          two  convertible          rwd           front           88.6  ...
# 2          two    hatchback          rwd           front           94.5  ...
# 3         four        sedan          fwd           front           99.8  ...
# 4         four        sedan          4wd           front           99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %% [markdown]
# ###### Define

# %% [markdown]
# Rename `length` column with `length-in` refer the unit of it by inche

# %% [markdown]
# ###### Code

# %%
df_clean.rename(columns={'length': 'length-in'}, inplace=True)

# %% [markdown]
# ###### Test

# %%
df_clean.head()
# Out:
#    symboling normalized-losses Vehicle-Types fuel-type aspiration  \
# 0          3              None   alfa-romero       gas        std
# 1          3              None   alfa-romero       gas        std
# 2          1              None   alfa-romero       gas        std
# 3          2               164          audi       gas        std
# 4          2               164          audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base_in  ...  \
# 0          two  convertible          rwd           front           88.6  ...
# 1          two  convertible          rwd           front           88.6  ...
# 2          two    hatchback          rwd           front           94.5  ...
# 3         four        sedan          fwd           front           99.8  ...
# 4         four        sedan          4wd           front           99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %% [markdown]
# ###### Define

# %% [markdown]
# Rename `width` column with `width-in` refer the unit of it by inche

# %% [markdown]
# ###### Code

# %%
df_clean.rename(columns={'width': 'width-in'}, inplace=True)

# %% [markdown]
# ###### Test

# %%
df_clean.head()
# Out:
#    symboling normalized-losses Vehicle-Types fuel-type aspiration  \
# 0          3              None   alfa-romero       gas        std
# 1          3              None   alfa-romero       gas        std
# 2          1              None   alfa-romero       gas        std
# 3          2               164          audi       gas        std
# 4          2               164          audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base_in  ...  \
# 0          two  convertible          rwd           front           88.6  ...
# 1          two  convertible          rwd           front           88.6  ...
# 2          two    hatchback          rwd           front           94.5  ...
# 3         four        sedan          fwd           front           99.8  ...
# 4         four        sedan          4wd           front           99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %% [markdown]
# ###### Define

# %% [markdown]
# Rename `height` column with `height-in` refer the unit of it by inche

# %% [markdown]
# ###### Code

# %%
df_clean.rename(columns={'height': 'height-in'}, inplace=True)

# %% [markdown]
# ###### Test

# %%
df_clean.head()
# Out:
#    symboling normalized-losses Vehicle-Types fuel-type aspiration  \
# 0          3              None   alfa-romero       gas        std
# 1          3              None   alfa-romero       gas        std
# 2          1              None   alfa-romero       gas        std
# 3          2               164          audi       gas        std
# 4          2               164          audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base_in  ...  \
# 0          two  convertible          rwd           front           88.6  ...
# 1          two  convertible          rwd           front           88.6  ...
# 2          two    hatchback          rwd           front           94.5  ...
# 3         four        sedan          fwd           front           99.8  ...
# 4         four        sedan          4wd           front           99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %% [markdown]
# ###### Define

# %% [markdown]
# Rename `engine-size` column with `engine-size-cu_in` refer the unit of it by inche

# %% [markdown]
# ###### Code

# %%
df_clean.rename(columns={'engine-size': 'engine-size-cu_in'}, inplace=True)

# %% [markdown]
# ###### Test

# %%
df_clean.head()
# Out:
#    symboling normalized-losses Vehicle-Types fuel-type aspiration  \
# 0          3              None   alfa-romero       gas        std
# 1          3              None   alfa-romero       gas        std
# 2          1              None   alfa-romero       gas        std
# 3          2               164          audi       gas        std
# 4          2               164          audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base_in  ...  \
# 0          two  convertible          rwd           front           88.6  ...
# 1          two  convertible          rwd           front           88.6  ...
# 2          two    hatchback          rwd           front           94.5  ...
# 3         four        sedan          fwd           front           99.8  ...
# 4         four        sedan          4wd           front           99.4  ...
#
#    engine-size-cu_in  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %% [markdown]
# ###### Define

# %% [markdown]
# Rename `curb-weight` column with `curb-weight-lbs` refer the unit of it by inche

# %% [markdown]
# ###### Code

# %%
df_clean.rename(columns={'curb-weight': 'curb-weight-lbs'}, inplace=True)

# %% [markdown]
# ###### Test

# %%
df_clean.head()
# Out:
#    symboling normalized-losses Vehicle-Types fuel-type aspiration  \
# 0          3              None   alfa-romero       gas        std
# 1          3              None   alfa-romero       gas        std
# 2          1              None   alfa-romero       gas        std
# 3          2               164          audi       gas        std
# 4          2               164          audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base_in  ...  \
# 0          two  convertible          rwd           front           88.6  ...
# 1          two  convertible          rwd           front           88.6  ...
# 2          two    hatchback          rwd           front           94.5  ...
# 3         four        sedan          fwd           front           99.8  ...
# 4         four        sedan          4wd           front           99.4  ...
#
#    engine-size-cu_in  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %% [markdown]
# # Data after Cleaning

# %%
df_clean
# Out:
#      symboling normalized-losses Vehicle-Types fuel-type aspiration  \
# 0            3              None   alfa-romero       gas        std
# 1            3              None   alfa-romero       gas        std
# 2            1              None   alfa-romero       gas        std
# 3            2               164          audi       gas        std
# 4            2               164          audi       gas        std
# ..         ...               ...           ...       ...        ...
# 200         -1                95         volvo       gas        std
# 201         -1                95         volvo       gas      turbo
# 202         -1                95         volvo       gas        std
# 203         -1                95         volvo    diesel      turbo
# 204         -1                95         volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base_in  \
# 0            two  convertible          rwd           front           88.6
# ...
